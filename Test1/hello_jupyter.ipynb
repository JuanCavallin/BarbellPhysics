# %%
import certifi
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = 'mongodb+srv://juancavallin:password@cavallin.1qowuux.mongodb.net/?retryWrites=true&w=majority'

# Create a new client and connect to the server
cluster = MongoClient(uri, server_api=ServerApi('1'), tlsCAFile=certifi.where())
cloud_database = cluster["UserData"]
collection = cloud_database["User_Landmarks"]

try:
    cluster.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

#Information about the POST request
#post = {"_id":2, "name": "Juan", "score": 100}
#collection.insert_one(post)
results = collection.find({})

for result in results:
    print(result)
    
#collection.delete_one({"_id":0})

#update = collection.update_one({"name": "Juan"}, {"$set": {"name": "Andres"}})
update = collection.update_many({"name": "Andres"}, {"$inc": {"score": 100}})

post_count = collection.count_documents({})
print(post_count)

delete = collection.delete_many({})
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# {'_id': '2023-07-31_23-06-00700-squat-edit_1', 'rf_prob': 0.97, 'rc_prob': 0.92, 'gb_prob': 0.99}
# {'_id': '2023-07-31_23-06-00700-squat-edit_2', 'rf_prob': 1.0, 'rc_prob': 0.84, 'gb_prob': 1.0}
# {'_id': '2023-07-31_23-06-00700-squat-edit_3', 'rf_prob': 0.98, 'rc_prob': 0.86, 'gb_prob': 0.99}
# {'_id': '2023-07-31_23-06-00700-squat-edit_4', 'rf_prob': 0.99, 'rc_prob': 0.89, 'gb_prob': 0.99}
# {'_id': '2023-07-31_23-06-00700-squat-edit_5', 'rf_prob': 0.99, 'rc_prob': 0.95, 'gb_prob': 0.99}
# {'_id': '2023-07-31_23-06-00700-squat-edit_6', 'rf_prob': 1.0, 'rc_prob': 0.97, 'gb_prob': 0.99}
# {'_id': '2023-07-31_23-06-00700-squat-edit_7', 'rf_prob': 1.0, 'rc_prob': 0.99, 'gb_prob': 0.99}
# {'_id': '2023-07-31_23-06-00700-squat-edit_8', 'rf_prob': 1.0, 'rc_prob': 0.98, 'gb_prob': 0.99}
# {'_id': '2023-07-31_23-06-00700-squat-edit_9', 'rf_prob': 1.0, 'rc_prob': 0.93, 'gb_prob': 0.99}
# ...
